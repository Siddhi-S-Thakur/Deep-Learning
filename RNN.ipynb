# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhi-S-Thakur/Deep-Learning/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
(x_train, ytrain),(x_test, y_test) = keras.datasets.imdb.load_data(num_words=10000)

# %%
x_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
# ...

# %%
x_train.shape
# Out:
# (25000,)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(x_train, maxlen = 500)
x_test = pad_sequences(x_train, maxlen = 500)

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, SimpleRNN, Embedding

# model = Sequential([
#     Embedding(10000,16),
#     SimpleRNN(32, return_sequences = True),
#     SimpleRNN(32, activation = "tanh"),
#     Dense(1,activation = "sigmoid")
#     ])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding

model1 = Sequential([
    Embedding(10000,16),
    LSTM(32, return_sequences = True),
    LSTM(32, activation = "tanh"),
    Dense(1,activation = "sigmoid")
    ])

# %%
# model.compile(optimizer = 'adam', loss= 'binary_crossentropy', metrics = ['accuracy'])

# %%
model1.compile(optimizer = 'adam', loss= 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train, ytrain, epochs = 5, validation_data = (x_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 138s 173ms/step - accuracy: 0.5297 - loss: 0.6861 - val_accuracy: 0.4935 - val_loss: 0.9020
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 175ms/step - accuracy: 0.7585 - loss: 0.4997 - val_accuracy: 0.4952 - val_loss: 0.9412
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 114s 146ms/step - accuracy: 0.8503 - loss: 0.3540 - val_accuracy: 0.4991 - val_loss: 1.4084
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 143s 147ms/step - accuracy: 0.9150 - loss: 0.2227 - val_accuracy: 0.4960 - val_loss: 1.6905
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 113s 145ms/step - accuracy: 0.9074 - loss: 0.2294 - val_accuracy: 0.4973 - val_loss: 1.9823

# %%
model1.fit(x_train, ytrain, epochs = 5, validation_data = (x_test, y_test))
# Out:
# Epoch 1/5
# 665/782 ━━━━━━━━━━━━━━━━━━━━ 23s 203ms/step - accuracy: 0.7073 - loss: 0.5289

# %%
model.evaluate(x_test, y_test)   # this returns [loss,accuracy]
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.4920 - loss: 2.0025
# [1.982304334640503, 0.4973199963569641]

# %%
model1.evaluate(x_test, y_test)
